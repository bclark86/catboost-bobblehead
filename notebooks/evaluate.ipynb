# %%
import os
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '..')

# %%
model_path = os.path.join('..', 'model', 'estimator.pkl')
model = joblib.load(model_path)

# %%
test_df = pd.read_csv(os.path.join('..', 'data', 'training', 'test.csv'))

# %%
test_df.head()
# Out:
#    year             home_team month  day  attend day_of_week  \
# 0  2012       Cincinnati Reds   JUN   25   34485      Monday
# 1  2012     Toronto Blue Jays   MAY   16   28915   Wednesday
# 2  2012  Arizona Diamondbacks   AUG   29   18451   Wednesday
# 3  2012      New York Yankees   AUG    5   45878      Sunday
# 4  2012     Toronto Blue Jays   JUN   28   24668    Thursday
#
#              opponent  temp   skies day_night cap shirt fireworks bobblehead
# 0   Milwaukee Brewers    84   Clear     Night  NO    NO        NO         NO
# 1    New York Yankees    68    Dome     Night  NO    NO        NO         NO
# 2     Cincinnati Reds    76    Dome       Day  NO    NO        NO         NO
# 3    Seattle Mariners    89  Cloudy       Day  NO    NO        NO         NO
# 4  Los Angeles Angels    73   Clear     Night  NO    NO        NO         NO

# %%
test_df['predicted_attend'] = np.round(model.predict(test_df))

# %%
train_df = pd.read_csv(os.path.join('..', 'data', 'training', 'train.csv'))

# %%
train_df['predicted_attend'] = np.round(model.predict(train_df))

# %%
full_df = pd.concat([train_df, test_df], keys=['train', 'test'])
full_df.index = full_df.index.get_level_values(0)
full_df = full_df.reset_index().rename(columns={'index': 'data'})

# %%
full_df
# Out:
#        data  year             home_team month  day  attend day_of_week  \
# 0     train  2012         New York Mets   SEP    8   25603    Saturday
# 1     train  2012   Los Angeles Dodgers   MAY   18   40906      Friday
# 2     train  2012    Pittsburgh Pirates   MAY   13   27517      Sunday
# 3     train  2012     Chicago White Sox   SEP    5   17336   Wednesday
# 4     train  2012        Atlanta Braves   JUN   12   41452     Tuesday
# ...     ...   ...                   ...   ...  ...     ...         ...
# 2416   test  2012        Atlanta Braves   MAY   25   37663      Friday
# 2417   test  2012  Washington Nationals   SEP    4   17648     Tuesday
# 2418   test  2012    Pittsburgh Pirates   JUN   10   25752      Sunday
# 2419   test  2012   St. Louis Cardinals   MAY    1   36345     Tuesday
# 2420   test  2012       Cincinnati Reds   JUN   12   24758     Tuesday
#
#                   opponent  temp   skies day_night cap shirt fireworks  \
# 0           Atlanta Braves    83  Cloudy       Day  NO    NO        NO
# 1      St. Louis Cardinals    64   Clear     Night  NO    NO       YES
# 2           Houston Astros    62   Rainy       Day  NO   YES        NO
# 3          Minnesota Twins    85  Cloudy       Day  NO    NO        NO
# 4         New York Yankees    84  Cloudy     Night  NO    NO        NO
# ...                    ...   ...     ...       ...  ..   ...       ...
# 2416  Washington Nationals    88  Cloudy     Night  NO    NO       YES
# 2417          Chicago Cubs    82  Cloudy     Night  NO    NO        NO
# 2418    Kansas City Royals    85   Clear       Day  NO    NO        NO
# 2419    Pittsburgh Pirates    83  Cloudy     Night  NO    NO        NO
# 2420     Cleveland Indians    86   Clear     Night  NO    NO        NO
#
#      bobblehead  predicted_attend
# 0            NO           25319.0
# 1            NO           37437.0
# 2            NO           28241.0
# 3            NO           19535.0
# 4            NO           38581.0
# ...         ...               ...
# 2416         NO           36919.0
# 2417         NO           21351.0
# 2418         NO           34625.0
# 2419         NO           39639.0
# 2420         NO           25469.0
#
# [2421 rows x 16 columns]

# %%
import altair as alt

scatter = alt.Chart(full_df).mark_circle(size=60).encode(
    x=alt.X('attend', axis=alt.Axis(format="~s", title='Actual Attendance')),
    y=alt.X('predicted_attend', axis=alt.Axis(format="~s", title='Predicted Attendance')),
    color=alt.Color('data', scale=alt.Scale(range=['#d62728', '#7f7f7f'])),
    tooltip=['home_team', 'opponent', 'month', 'day',
             'attend', 'predicted_attend',
             'day_of_week', 'temp', 'skies', 'day_night', 
             'cap', 'shirt', 'fireworks', 'bobblehead']
).properties(
    title='Predictive Performance'
)

overlay_df = pd.DataFrame({
    'x': np.round(np.linspace(0, 60_000, 100))
})

overlay_df['y'] = overlay_df.x

line = alt.Chart(overlay_df).mark_line(color='black', strokeWidth=0.25).encode(
    x='x', y='y'
)

scatter + line
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     372         if dct is None:
#     373             kwargs['validate'] = 'deep'
# --> 374             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     375
#     376         # TODO: following entries are added after validation. Should they be validated?
#
# /usr/local/lib/python3.7/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     297             result = _todict({k: v for k, v in self._kwds.items()
#     298                               if k not in ignore},
# --> 299                               validate=sub_validate, context=context)
#     300         else:
#     301             raise ValueError("{} instance has both a value and properties : "
#
# /usr/local/lib/python3.7/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {k: _todict(v, validate, context) for k, v in obj.items()
#      61                 if v is not Undefined}
#      62     elif hasattr(obj, 'to_dict'):
#
# /usr/local/lib/python3.7/site-packages/altair/utils/schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {k: _todict(v, validate, context) for k, v in obj.items()
# ---> 61                 if v is not Undefined}
#      62     elif hasattr(obj, 'to_dict'):
#      63         return obj.to_dict()
#
# /usr/local/lib/python3.7/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {k: _todict(v, validate, context) for k, v in obj.items()
#
# /usr/local/lib/python3.7/site-packages/altair/utils/schemapi.py in <listcomp>(.0)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {k: _todict(v, validate, context) for k, v in obj.items()
#
# /usr/local/lib/python3.7/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# /usr/local/lib/python3.7/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     372         if dct is None:
#     373             kwargs['validate'] = 'deep'
# --> 374             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     375
#     376         # TODO: following entries are added after validation. Should they be validated?
#
# /usr/local/lib/python3.7/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     305                 self.validate(result)
#     306             except jsonschema.ValidationError as err:
# --> 307                 raise SchemaValidationError(self, err)
#     308         return result
#     309
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.api.Chart, validating 'additionalProperties'
#
#         Additional properties are not allowed ('subtitle' was unexpected)
# alt.LayerChart(...)

# %%
overlay_df = pd.DataFrame({
    'x': np.round(np.linspace(0, 60_000, 100))
})

overlay_df['y'] = overlay_df.x
